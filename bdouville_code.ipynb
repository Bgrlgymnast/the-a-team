# %%
import pandas as pd
import numpy as np

# %%
#Updated the csv -Kev
gdp_df= pd.read_csv("GDP_logregressed.csv")
gdp_df
# Out:
#      Year Nominal GDP (million of Dollars)  \
# 0    1787                           125.45
# 1    1788                           131.89
# 2    1789                           138.66
# 3    1790                              193
# 4    1791                              210
# ..    ...                              ...
# 232  2019                       21,521,395
# 233  2020                       21,322,950
# 234  2021                       23,594,031
# 235  2022                       25,744,108
# 236  2023                       27,360,900
#
#     Real GDP (millions of 2017 dollars)  GDP Deflator (index 2017=100)  \
# 0                               6411.44                           1.96
# 1                               6648.35                           1.98
# 2                               6894.01                           2.01
# 3                                 4,975                           3.88
# 4                                 5,274                           3.98
# ..                                  ...                            ...
# 232                          20,692,100                         104.01
# 233                          20,234,100                         105.41
# 234                          21,407,700                         110.22
# 235                          21,822,000                         118.00
# 236                          22,376,900                         122.27
#
#       Population Nominal GDP per capita (current dollars)  \
# 0     6450056.32                                    19.45
# 1     6573085.52                                    20.07
# 2     6698461.39                                     20.7
# 3      3,929,000                                     49.1
# 4      4,048,000                                    51.89
# ..           ...                                      ...
# 232  330,513,000                                65,115.12
# 233  331,800,000                                64,266.79
# 234  332,367,000                                70,991.30
# 235  333,568,000                                77,171.74
# 236  335,208,000                                81,623.65
#
#     Real GDP per capita (year 2017 dollars)
# 0                                    994.01
# 1                                   1011.45
# 2                                   1029.19
# 3                                  1,266.23
# 4                                  1,302.85
# ..                                      ...
# 232                               62,606.01
# 233                               60,985.03
# 234                               64,412.92
# 235                               65,414.65
# 236                               66,755.27
#
# [237 rows x 7 columns]

# %%
presidents_df= pd.read_csv("all_us_presidents.csv")
presidents_df.head()
# Out:
#    Years (after inauguration)          President Party
# 0                        1789  George Washington   NaN
# 1                        1790  George Washington   NaN
# 2                        1791  George Washington   NaN
# 3                        1792  George Washington   NaN
# 4                        1793  George Washington   NaN

# %%
# get values for the years after 2013 for year column
add_years_after_inaguration = presidents_df["Years (after inauguration)"].iloc[-1]

# adding new rows that include Years (after inauguration), name of president and party
new_rows = {
    "Years (after inauguration)": [add_years_after_inaguration + i for i in range(1, 11)],
    "President": ['Barack Obama'] * 3 + ['Donald Trump'] * 4 + ['Joe Biden'] * 3,
    "Party": ['Democrat'] * 3 + ['Republican'] * 4 + ['Democrat'] * 3
}

#new_rows

# %%
presidents_df.rename(columns={'Years (after inauguration)': 'Year'}, inplace=True)
presidents_df.head()
# Out:
#    Year          President Party
# 0  1789  George Washington   NaN
# 1  1790  George Washington   NaN
# 2  1791  George Washington   NaN
# 3  1792  George Washington   NaN
# 4  1793  George Washington   NaN

# %%
updated_pres_df =pd.DataFrame(new_rows)
updated_pres_df
# Out:
#    Years (after inauguration)     President       Party
# 0                        2014  Barack Obama    Democrat
# 1                        2015  Barack Obama    Democrat
# 2                        2016  Barack Obama    Democrat
# 3                        2017  Donald Trump  Republican
# 4                        2018  Donald Trump  Republican
# 5                        2019  Donald Trump  Republican
# 6                        2020  Donald Trump  Republican
# 7                        2021     Joe Biden    Democrat
# 8                        2022     Joe Biden    Democrat
# 9                        2023     Joe Biden    Democrat

# %%
updated_pres_df.rename(columns={'Years (after inauguration)': 'Year'}, inplace=True)
updated_pres_df
# Out:
#    Year     President       Party
# 0  2014  Barack Obama    Democrat
# 1  2015  Barack Obama    Democrat
# 2  2016  Barack Obama    Democrat
# 3  2017  Donald Trump  Republican
# 4  2018  Donald Trump  Republican
# 5  2019  Donald Trump  Republican
# 6  2020  Donald Trump  Republican
# 7  2021     Joe Biden    Democrat
# 8  2022     Joe Biden    Democrat
# 9  2023     Joe Biden    Democrat

# %%
updated_pres_df.rename(columns={'Years (after inauguration)': 'Year'}, inplace=True)
updated_pres_df
# Out:
#    Year     President       Party
# 0  2014  Barack Obama    Democrat
# 1  2015  Barack Obama    Democrat
# 2  2016  Barack Obama    Democrat
# 3  2017  Donald Trump  Republican
# 4  2018  Donald Trump  Republican
# 5  2019  Donald Trump  Republican
# 6  2020  Donald Trump  Republican
# 7  2021     Joe Biden    Democrat
# 8  2022     Joe Biden    Democrat
# 9  2023     Joe Biden    Democrat

# %%
cleaned_pres_df=pd.concat([presidents_df,updated_pres_df])
cleaned_pres_df.head(15)
# Out:
#     Year          President                  Party
# 0   1789  George Washington                    NaN
# 1   1790  George Washington                    NaN
# 2   1791  George Washington                    NaN
# 3   1792  George Washington                    NaN
# 4   1793  George Washington                    NaN
# 5   1794  George Washington                    NaN
# 6   1795  George Washington                    NaN
# 7   1796  George Washington                    NaN
# 8   1797         John Adams             Federalist
# 9   1798         John Adams             Federalist
# 10  1799         John Adams             Federalist
# 11  1800         John Adams             Federalist
# 12  1801   Thomas Jefferson  Democratic-Republican
# 13  1802   Thomas Jefferson  Democratic-Republican
# 14  1803   Thomas Jefferson  Democratic-Republican

# %%
cleaned_pres_df.to_csv("cleaned_pres_df.csv", index=False)

# %%
presidentfinal_df =pd.merge(cleaned_pres_df, gdp_df, on="Year")
presidentfinal_df.head(10)
# Out:
#    Year          President       Party Nominal GDP (million of Dollars)  \
# 0  1789  George Washington         NaN                           138.66
# 1  1790  George Washington         NaN                              193
# 2  1791  George Washington         NaN                              210
# 3  1792  George Washington         NaN                              230
# 4  1793  George Washington         NaN                              256
# 5  1794  George Washington         NaN                              321
# 6  1795  George Washington         NaN                              390
# 7  1796  George Washington         NaN                              423
# 8  1797         John Adams  Federalist                              415
# 9  1798         John Adams  Federalist                              418
#
#   Real GDP (millions of 2017 dollars)  GDP Deflator (index 2017=100)  \
# 0                             6894.01                           2.01
# 1                               4,975                           3.88
# 2                               5,274                           3.98
# 3                               5,663                           4.05
# 4                               6,113                           4.19
# 5                               6,905                           4.65
# 6                               7,331                           5.32
# 7                               7,553                           5.60
# 8                               7,692                           5.39
# 9                               8,009                           5.22
#
#    Population Nominal GDP per capita (current dollars)  \
# 0  6698461.39                                     20.7
# 1   3,929,000                                     49.1
# 2   4,048,000                                    51.89
# 3   4,171,000                                    55.03
# 4   4,297,000                                    59.67
# 5   4,428,000                                    72.56
# 6   4,562,000                                    85.53
# 7   4,700,000                                    90.06
# 8   4,843,000                                    85.65
# 9   4,990,000                                    83.73
#
#   Real GDP per capita (year 2017 dollars)
# 0                                 1029.19
# 1                                1,266.23
# 2                                1,302.85
# 3                                1,357.63
# 4                                1,422.52
# 5                                1,559.46
# 6                                1,607.03
# 7                                1,606.92
# 8                                1,588.26
# 9                                1,605.09

# %%
presidentfinal_df.to_csv("presidentfinal_df.csv", index=False)

# %%
#importing birthdate of presidents csv
birthday_df= pd.read_csv("birthdates-of-us-presidents.csv")
birthday_df.rename(columns={'Date of Birth': 'birthday'}, inplace=True)
birthday_df['birthday'] = pd.to_datetime(birthday_df['birthday'])
birthday_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 4
#       2 birthday_df= pd.read_csv("birthdates-of-us-presidents.csv")
#       3 birthday_df.rename(columns={'Date of Birth': 'birthday'}, inplace=True)
# ----> 4 birthday_df['birthday'] = pd.to_datetime(birthday_df['birthday'])
#       5 birthday_df.head()
#
# File c:\Users\User\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1112, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1110         result = arg.map(cache_array)
#    1111     else:
# -> 1112         values = convert_listlike(arg._values, format)
#    1113         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1114 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Users\User\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:488, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     486 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     487 if format is not None and format != "mixed":
# --> 488     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     490 result, tz_parsed = objects_to_datetime64ns(
#     491     arg,
#     492     dayfirst=dayfirst,
#    (...)
#     496     allow_object=True,
#     497 )
#     499 if tz_parsed is not None:
#     500     # We can take a shortcut since the datetime64 numpy array
#     501     # is in UTC
#
# File c:\Users\User\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:519, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     508 def _array_strptime_with_fallback(
#     509     arg,
#     510     name,
#    (...)
#     514     errors: str,
#     515 ) -> Index:
#     516     """
#     517     Call array_strptime, with fallback behavior depending on 'errors'.
#     518     """
# --> 519     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     520     if any(tz is not None for tz in timezones):
#     521         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File strptime.pyx:534, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:355, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data "9/1/1913" doesn't match format "%Y-%m-%d", at position 1. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
#importing presidential zodiac sign csv
zodiac_df= pd.read_csv("presidential_zodiac_sign.csv")
zodiac_df.rename(columns={'Birthday': 'birthday'})
zodiac_df
# Out:
#         President    Birthday         Sign
# 0      Washington  1732-02-22       Pisces
# 1        J. Adams  1735-10-30      Scorpio
# 2       Jefferson  1743-04-13        Aries
# 3         Madison  1751-03-16       Pisces
# 4          Monroe  1758-04-28       Taurus
# 5      J.Q. Adams  1767-07-11       Cancer
# 6         Jackson  1767-03-15       Pisces
# 7       Van Buren  1782-12-05  Sagittarius
# 8   W.H. Harrison  1773-02-09     Aquarius
# 9            Polk  1795-11-02      Scorpio
# 10         Taylor  1784-11-24  Sagittarius
# 11         Pierce  1804-11-23  Sagittarius
# 12       Buchanan  1791-04-23       Taurus
# 13        Lincoln  1809-02-12     Aquarius
# 14          Grant  1822-04-27       Taurus
# 15          Hayes  1822-10-04        Libra
# 16       Garfield  1831-11-19      Scorpio
# 17      Cleveland  1837-03-18       Pisces
# 18    B. Harrison  1833-08-20          Leo
# 19       McKinley  1843-01-29     Aquarius
# 20   T. Roosevelt  1858-10-27      Scorpio
# 21           Taft  1857-09-15        Virgo
# 22         Wilson  1856-12-28    Capricorn
# 23        Harding  1865-11-02      Scorpio
# 24       Coolidge  1872-07-04       Cancer
# 25         Hoover  1874-08-10          Leo
# 26   F. Roosevelt  1882-01-30     Aquarius
# 27         Truman  1884-05-08       Taurus
# 28     Eisenhower  1890-10-14        Libra
# 29        Kennedy   5/29/2017       Gemini
# 30     L. Johnson   8/27/1908        Virgo
# 31          Nixon    1/9/1913    Capricorn
# 32         Carter   10/1/1924        Libra
# 33         Reagan    2/6/1911     Aquarius
# 34    G.H.W. Bush   6/12/1924       Gemini
# 35        Clinton   8/19/1946          Leo
# 36      G.W. Bush    7/6/1946       Cancer
# 37          Obama    8/4/1961          Leo
# 38          Trump   1946-0614       Gemini
# 39          Biden  11/20/1942       Taurus

# %%
pres_zodiac_df =pd.merge(birthday_df, zodiac_df, on='birthday')
pres_zodiac_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5980\4006739708.py in ?()
# ----> 1 pres_zodiac_df =pd.merge(birthday_df, zodiac_df, on='birthday')
#       2 pres_zodiac_df.head(10)
#
# c:\Users\User\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     165             validate=validate,
#     166             copy=copy,
#     167         )
#     168     else:
# --> 169         op = _MergeOperation(
#     170             left_df,
#     171             right_df,
#     172             how=how,
#
# c:\Users\User\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     787             self.right_join_keys,
#     788             self.join_names,
#     789             left_drop,
#     790             right_drop,
# --> 791         ) = self._get_merge_keys()
#     792
#     793         if left_drop:
#     794             self.left = self.left._drop_labels_or_levels(left_drop)
#
# c:\Users\User\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1265                         # Then we're either Hashable or a wrong-length arraylike,
#    1266                         #  the latter of which will raise
#    1267                         rk = cast(Hashable, rk)
#    1268                         if rk is not None:
# -> 1269                             right_keys.append(right._get_label_or_level_values(rk))
#    1270                         else:
#    1271                             # work-around for merge_asof(right_index=True)
#    1272                             right_keys.append(right.index._values)
#
# c:\Users\User\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
#    1841         elif self._is_level_reference(key, axis=axis):
#    1842             values = self.axes[axis].get_level_values(key)._values
#    1843         else:
# -> 1844             raise KeyError(key)
#    1845
#    1846         # Check for duplicates
#    1847         if values.ndim > 1:
#
# KeyError: 'birthday'
