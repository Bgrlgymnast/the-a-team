# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# %%
pres_gdp = pd.read_csv("presidentfinal_df.csv")
pres_bday = pd.read_csv("birthdates-of-us-presidents.csv")
pres_bday=pres_bday.drop("csvbase_row_id",axis=1)
pres_bday = pres_bday.rename(columns={"Date of birth":"birthday","Name":"name"})
pres_gdp=pres_gdp.rename(columns={  'Year':'year',
                                    'President':'president',
                                    'Party':'party',
                                    'Nominal GDP (million of Dollars)':"nominal_gdp(million_of_dollars)",
                                    'Real GDP (millions of 2017 dollars)':'real_gdp(millions_of_2017_dollars)',
                                    'GDP Deflator (index 2017=100)':'gdp_deflator_(index_2017=100)',
                                    'Population':'population',
                                    'Nominal GDP per capita (current dollars)':'nominal_gdp_per_capita_(current_dollars)',
                                    'Real GDP per capita (year 2017 dollars)':'real_gdp_per_capita_(year_2017_dollars)'
})

# %%
pres_gdp.head(10)
# Out:
#    year          president       party nominal_gdp(million_of_dollars)  \
# 0  1789  George Washington         NaN                          138.66
# 1  1790  George Washington         NaN                             193
# 2  1791  George Washington         NaN                             210
# 3  1792  George Washington         NaN                             230
# 4  1793  George Washington         NaN                             256
# 5  1794  George Washington         NaN                             321
# 6  1795  George Washington         NaN                             390
# 7  1796  George Washington         NaN                             423
# 8  1797         John Adams  Federalist                             415
# 9  1798         John Adams  Federalist                             418
#
#   real_gdp(millions_of_2017_dollars)  gdp_deflator_(index_2017=100)  \
# 0                            6894.01                           2.01
# 1                              4,975                           3.88
# 2                              5,274                           3.98
# 3                              5,663                           4.05
# 4                              6,113                           4.19
# 5                              6,905                           4.65
# 6                              7,331                           5.32
# 7                              7,553                           5.60
# 8                              7,692                           5.39
# 9                              8,009                           5.22
#
#    population nominal_gdp_per_capita_(current_dollars)  \
# 0  6698461.39                                     20.7
# 1   3,929,000                                     49.1
# 2   4,048,000                                    51.89
# 3   4,171,000                                    55.03
# 4   4,297,000                                    59.67
# 5   4,428,000                                    72.56
# 6   4,562,000                                    85.53
# 7   4,700,000                                    90.06
# 8   4,843,000                                    85.65
# 9   4,990,000                                    83.73
#
#   real_gdp_per_capita_(year_2017_dollars)
# 0                                 1029.19
# 1                                1,266.23
# 2                                1,302.85
# 3                                1,357.63
# 4                                1,422.52
# 5                                1,559.46
# 6                                1,607.03
# 7                                1,606.92
# 8                                1,588.26
# 9                                1,605.09

# %%
pres_bday = pres_bday.rename(columns={"name" : "president"})
pres_bday.head()
# Out:
#            president    birthday
# 0  George Washington  1732-02-22
# 1         John Adams  1735-10-30
# 2   Thomas Jefferson  1743-04-13
# 3      James Madison  1751-03-16
# 4       James Monroe  1758-04-28

# %%
joined_df = pres_bday.merge(pres_gdp, on="president", how="left")

joined_df.head()
# Out:
#            president    birthday    year party  \
# 0  George Washington  1732-02-22  1789.0   NaN
# 1  George Washington  1732-02-22  1790.0   NaN
# 2  George Washington  1732-02-22  1791.0   NaN
# 3  George Washington  1732-02-22  1792.0   NaN
# 4  George Washington  1732-02-22  1793.0   NaN
#
#   nominal_gdp(million_of_dollars) real_gdp(millions_of_2017_dollars)  \
# 0                          138.66                            6894.01
# 1                             193                              4,975
# 2                             210                              5,274
# 3                             230                              5,663
# 4                             256                              6,113
#
#    gdp_deflator_(index_2017=100)  population  \
# 0                           2.01  6698461.39
# 1                           3.88   3,929,000
# 2                           3.98   4,048,000
# 3                           4.05   4,171,000
# 4                           4.19   4,297,000
#
#   nominal_gdp_per_capita_(current_dollars)  \
# 0                                     20.7
# 1                                     49.1
# 2                                    51.89
# 3                                    55.03
# 4                                    59.67
#
#   real_gdp_per_capita_(year_2017_dollars)
# 0                                 1029.19
# 1                                1,266.23
# 2                                1,302.85
# 3                                1,357.63
# 4                                1,422.52

# %%
base_df = joined_df.copy()

base_df= base_df[['president', 'birthday','year','party','nominal_gdp(million_of_dollars)','nominal_gdp_per_capita_(current_dollars)']]

base_df.head()
# Out:
#            president    birthday    year party  \
# 0  George Washington  1732-02-22  1789.0   NaN
# 1  George Washington  1732-02-22  1790.0   NaN
# 2  George Washington  1732-02-22  1791.0   NaN
# 3  George Washington  1732-02-22  1792.0   NaN
# 4  George Washington  1732-02-22  1793.0   NaN
#
#   nominal_gdp(million_of_dollars) nominal_gdp_per_capita_(current_dollars)
# 0                          138.66                                     20.7
# 1                             193                                     49.1
# 2                             210                                    51.89
# 3                             230                                    55.03
# 4                             256                                    59.67

# %%
# Determine the number of unique values in each column.
base_df.nunique()
# Out:
# president                                    45
# birthday                                     45
# year                                        214
# party                                         6
# nominal_gdp(million_of_dollars)             214
# nominal_gdp_per_capita_(current_dollars)    214
# dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies` --- creates booleans of the categories
dummy_df1 = base_df[['president','party']]

dummy_df1.index=base_df['year']

dummy_df2 = pd.get_dummies(dummy_df1)

dummy_df2.head()
# Out:
#         president_Abraham Lincoln  president_Andrew Jackson  \
# year
# 1789.0                      False                     False
# 1790.0                      False                     False
# 1791.0                      False                     False
# 1792.0                      False                     False
# 1793.0                      False                     False
#
#         president_Andrew Johnson  president_Barack Obama  \
# year
# 1789.0                     False                   False
# 1790.0                     False                   False
# 1791.0                     False                   False
# 1792.0                     False                   False
# 1793.0                     False                   False
#
#         president_Benjamin Harrison  president_Bill Clinton  \
# year
# 1789.0                        False                   False
# 1790.0                        False                   False
# 1791.0                        False                   False
# 1792.0                        False                   False
# 1793.0                        False                   False
#
#         president_Calvin Coolidge  president_Chester A. Arthur  \
# year
# 1789.0                      False                        False
# 1790.0                      False                        False
# 1791.0                      False                        False
# 1792.0                      False                        False
# 1793.0                      False                        False
#
#         president_Donald Trump  president_Dwight D. Eisenhower  ...  \
# year                                                            ...
# 1789.0                   False                           False  ...
# 1790.0                   False                           False  ...
# 1791.0                   False                           False  ...
# 1792.0                   False                           False  ...
# 1793.0                   False                           False  ...
#
#         president_William Howard Taft  president_William McKinley  \
# year
# 1789.0                          False                       False
# 1790.0                          False                       False
# 1791.0                          False                       False
# 1792.0                          False                       False
# 1793.0                          False                       False
#
#         president_Woodrow Wilson  president_Zachary Taylor  party_Democrat  \
# year
# 1789.0                     False                     False           False
# 1790.0                     False                     False           False
# 1791.0                     False                     False           False
# 1792.0                     False                     False           False
# 1793.0                     False                     False           False
#
#         party_Democratic-Republican  party_Federalist  party_National Union  \
# year
# 1789.0                        False             False                 False
# 1790.0                        False             False                 False
# 1791.0                        False             False                 False
# 1792.0                        False             False                 False
# 1793.0                        False             False                 False
#
#         party_Republican  party_Whig
# year
# 1789.0             False       False
# 1790.0             False       False
# 1791.0             False       False
# 1792.0             False       False
# 1793.0             False       False
#
# [5 rows x 51 columns]

# %%
base_df2 = base_df.drop(['president','party'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-536f0b791561> in <cell line: 1>()
# ----> 1 base_df2 = base_df.drop(['president','party'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5342                 weight  1.0     0.8
#    5343         """
# -> 5344         return super().drop(
#    5345             labels=labels,
#    5346             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709         for axis, labels in axes.items():
#    4710             if labels is not None:
# -> 4711                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4712
#    4713         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4751                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4752             else:
# -> 4753                 new_axis = axis.drop(labels, errors=errors)
#    4754             indexer = axis.get_indexer(new_axis)
#    4755
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6998         if mask.any():
#    6999             if errors != "ignore":
# -> 7000                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001             indexer = indexer[~mask]
#    7002         return self.delete(indexer)
#
# KeyError: "['president', 'party'] not found in axis"

# %%
base_df2.head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-b46c1e32b157> in <cell line: 1>()
# ----> 1 base_df2.head(5)
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
pd.merge(base_df, dummy_df2, left_index=True, right_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-49e0122a7b6f> in <cell line: 1>()
# ----> 1 pd.merge(base_df, dummy_df2, left_index=True, right_index=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     149     validate: str | None = None,
#     150 ) -> DataFrame:
# --> 151     left_df = _validate_operand(left)
#     152     right_df = _validate_operand(right)
#     153     if how == "cross":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in _validate_operand(obj)
#    2630         return obj.to_frame()
#    2631     else:
# -> 2632         raise TypeError(
#    2633             f"Can only merge Series or DataFrame objects, a {type(obj)} was passed"
#    2634         )
#
# TypeError: Can only merge Series or DataFrame objects, a <class 'NoneType'> was passed

# %%
# Split our preprocessed data into our features and target arrays
# note that features are x = everything except price or whatever target, in this case what is successful?
# note that target array are y = price or target everything but the "successful column"
X = application_df.drop(columns='IS_SUCCESSFUL').values
y = application_df['IS_SUCCESSFUL'].values

# Split the preprocessed data into a training and testing dataset -- choose to stratify so that the classes are more balanced out bc it's a small dataset and imbalanced
X_train, X_test, y_train, y_test = train_test_split(X, y,stratify=y,test_size=.2, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

input_shape = X.shape[1] # number of columns in the dataset

# First hidden layer
nn.add(tf.keras.layers.Dense(units=128, activation='relu', input_shape=(input_shape,))) # first layer inputting shape to avoid keras error message

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=64, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()

# %%
# Compile the model

# define optimizer -- these can be adam(go-to), SGD(basic), RMSProp(RNN,online learning), Adagrad(sparse data, text processing), adadelta(better adagrad)
# define loss function -- these can be binary crossentropy, categorical crossentropy, mean squared or error (continuous data), hinge loss
# define metrics -- for classification like this--- this is usually "accuracy"

# Compile the model
nn.compile(optimizer='adam',
           loss='binary_crossentropy',    # Loss function: Binary crossentropy for binary classification
           metrics=['accuracy'])

# %%
# Train the model
nn.fit(X_train_scaled,
       y_train,
       epochs = 10,
       batch_size = 32,
       shuffle = True,
       verbose = 2,
       validation_data=(X_test_scaled, y_test))

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Export our model to HDF5 file
nn.save('alphabet_soupv1.h5')

#nn.save('alphabet_soupv1.keras')   # another way of saving this, but hw requires h5
