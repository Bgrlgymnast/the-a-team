# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import keras_tuner as kt
from keras_tuner import RandomSearch
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import Input

# %%
pres_gdp = pd.read_csv("presidentfinal_df.csv")
pres_bday = pd.read_csv("birthdates-of-us-presidents.csv")
pres_bday=pres_bday.drop("csvbase_row_id",axis=1)
pres_bday = pres_bday.rename(columns={"Date of birth":"birthday","Name":"name"})
pres_gdp=pres_gdp.rename(columns={  'Year':'year',
                                    'President':'president',
                                    'Party':'party',
                                    'Nominal GDP (million of Dollars)':"nominal_gdp(million_of_dollars)",
                                    'Real GDP (millions of 2017 dollars)':'real_gdp(millions_of_2017_dollars)',
                                    'GDP Deflator (index 2017=100)':'gdp_deflator_(index_2017=100)',
                                    'Population':'population',
                                    'Nominal GDP per capita (current dollars)':'nominal_gdp_per_capita_(current_dollars)',
                                    'Real GDP per capita (year 2017 dollars)':'real_gdp_per_capita_(year_2017_dollars)'
})

# %%
pres_gdp.head(10)
# Out:
#    year          president       party nominal_gdp(million_of_dollars)  \
# 0  1789  George Washington         NaN                          138.66
# 1  1790  George Washington         NaN                             193
# 2  1791  George Washington         NaN                             210
# 3  1792  George Washington         NaN                             230
# 4  1793  George Washington         NaN                             256
# 5  1794  George Washington         NaN                             321
# 6  1795  George Washington         NaN                             390
# 7  1796  George Washington         NaN                             423
# 8  1797         John Adams  Federalist                             415
# 9  1798         John Adams  Federalist                             418
#
#   real_gdp(millions_of_2017_dollars)  gdp_deflator_(index_2017=100)  \
# 0                            6894.01                           2.01
# 1                              4,975                           3.88
# 2                              5,274                           3.98
# 3                              5,663                           4.05
# 4                              6,113                           4.19
# 5                              6,905                           4.65
# 6                              7,331                           5.32
# 7                              7,553                           5.60
# 8                              7,692                           5.39
# 9                              8,009                           5.22
#
#    population nominal_gdp_per_capita_(current_dollars)  \
# 0  6698461.39                                     20.7
# 1   3,929,000                                     49.1
# 2   4,048,000                                    51.89
# 3   4,171,000                                    55.03
# 4   4,297,000                                    59.67
# 5   4,428,000                                    72.56
# 6   4,562,000                                    85.53
# 7   4,700,000                                    90.06
# 8   4,843,000                                    85.65
# 9   4,990,000                                    83.73
#
#   real_gdp_per_capita_(year_2017_dollars)
# 0                                 1029.19
# 1                                1,266.23
# 2                                1,302.85
# 3                                1,357.63
# 4                                1,422.52
# 5                                1,559.46
# 6                                1,607.03
# 7                                1,606.92
# 8                                1,588.26
# 9                                1,605.09

# %%
pres_bday = pres_bday.rename(columns={"name" : "president"})
pres_bday.head()
# Out:
#            president    birthday
# 0  George Washington  1732-02-22
# 1         John Adams  1735-10-30
# 2   Thomas Jefferson  1743-04-13
# 3      James Madison  1751-03-16
# 4       James Monroe  1758-04-28

# %%
joined_df = pres_bday.merge(pres_gdp, on="president", how="left")

joined_df['party'].fillna("none", inplace=True)

joined_df.fillna(0, inplace=True)

joined_df.head()
# Out:
#            president    birthday    year party  \
# 0  George Washington  1732-02-22  1789.0  none
# 1  George Washington  1732-02-22  1790.0  none
# 2  George Washington  1732-02-22  1791.0  none
# 3  George Washington  1732-02-22  1792.0  none
# 4  George Washington  1732-02-22  1793.0  none
#
#   nominal_gdp(million_of_dollars) real_gdp(millions_of_2017_dollars)  \
# 0                          138.66                            6894.01
# 1                             193                              4,975
# 2                             210                              5,274
# 3                             230                              5,663
# 4                             256                              6,113
#
#    gdp_deflator_(index_2017=100)  population  \
# 0                           2.01  6698461.39
# 1                           3.88   3,929,000
# 2                           3.98   4,048,000
# 3                           4.05   4,171,000
# 4                           4.19   4,297,000
#
#   nominal_gdp_per_capita_(current_dollars)  \
# 0                                     20.7
# 1                                     49.1
# 2                                    51.89
# 3                                    55.03
# 4                                    59.67
#
#   real_gdp_per_capita_(year_2017_dollars)
# 0                                 1029.19
# 1                                1,266.23
# 2                                1,302.85
# 3                                1,357.63
# 4                                1,422.52

# %%
base_df = joined_df.copy()

base_df= base_df[['president', 'birthday','year','party','nominal_gdp(million_of_dollars)','nominal_gdp_per_capita_(current_dollars)']]

base_df['nominal_gdp(million_of_dollars)']= base_df['nominal_gdp(million_of_dollars)'].str.replace(',', '').astype(float)
base_df['nominal_gdp_per_capita_(current_dollars)']= base_df['nominal_gdp_per_capita_(current_dollars)'].str.replace(',', '').astype(float)
base_df.head()
# Out:
#            president    birthday    year party  \
# 0  George Washington  1732-02-22  1789.0  none
# 1  George Washington  1732-02-22  1790.0  none
# 2  George Washington  1732-02-22  1791.0  none
# 3  George Washington  1732-02-22  1792.0  none
# 4  George Washington  1732-02-22  1793.0  none
#
#    nominal_gdp(million_of_dollars)  nominal_gdp_per_capita_(current_dollars)
# 0                           138.66                                     20.70
# 1                           193.00                                     49.10
# 2                           210.00                                     51.89
# 3                           230.00                                     55.03
# 4                           256.00                                     59.67

# %%
drop_df = base_df.drop(columns=["president",'party'])
drop_df.head()
# Out:
#      birthday    year  nominal_gdp(million_of_dollars)  \
# 0  1732-02-22  1789.0                           138.66
# 1  1732-02-22  1790.0                           193.00
# 2  1732-02-22  1791.0                           210.00
# 3  1732-02-22  1792.0                           230.00
# 4  1732-02-22  1793.0                           256.00
#
#    nominal_gdp_per_capita_(current_dollars)
# 0                                     20.70
# 1                                     49.10
# 2                                     51.89
# 3                                     55.03
# 4                                     59.67

# %%
# Convert categorical data to numeric with `pd.get_dummies` --- creates booleans of the categories
dummy_df1 = base_df[['president','party']]

dummy_df1.index=base_df['year']

dummy_df2 = pd.get_dummies(dummy_df1)

dummy_df2.head()
# Out:
#         president_Abraham Lincoln  president_Andrew Jackson  \
# year
# 1789.0                      False                     False
# 1790.0                      False                     False
# 1791.0                      False                     False
# 1792.0                      False                     False
# 1793.0                      False                     False
#
#         president_Andrew Johnson  president_Barack Obama  \
# year
# 1789.0                     False                   False
# 1790.0                     False                   False
# 1791.0                     False                   False
# 1792.0                     False                   False
# 1793.0                     False                   False
#
#         president_Benjamin Harrison  president_Bill Clinton  \
# year
# 1789.0                        False                   False
# 1790.0                        False                   False
# 1791.0                        False                   False
# 1792.0                        False                   False
# 1793.0                        False                   False
#
#         president_Calvin Coolidge  president_Chester A. Arthur  \
# year
# 1789.0                      False                        False
# 1790.0                      False                        False
# 1791.0                      False                        False
# 1792.0                      False                        False
# 1793.0                      False                        False
#
#         president_Donald Trump  president_Dwight D. Eisenhower  ...  \
# year                                                            ...
# 1789.0                   False                           False  ...
# 1790.0                   False                           False  ...
# 1791.0                   False                           False  ...
# 1792.0                   False                           False  ...
# 1793.0                   False                           False  ...
#
#         president_William McKinley  president_Woodrow Wilson  \
# year
# 1789.0                       False                     False
# 1790.0                       False                     False
# 1791.0                       False                     False
# 1792.0                       False                     False
# 1793.0                       False                     False
#
#         president_Zachary Taylor  party_Democrat  party_Democratic-Republican  \
# year
# 1789.0                     False           False                        False
# 1790.0                     False           False                        False
# 1791.0                     False           False                        False
# 1792.0                     False           False                        False
# 1793.0                     False           False                        False
#
#         party_Federalist  party_National Union  party_Republican  party_Whig  \
# year
# 1789.0             False                 False             False       False
# 1790.0             False                 False             False       False
# 1791.0             False                 False             False       False
# 1792.0             False                 False             False       False
# 1793.0             False                 False             False       False
#
#         party_none
# year
# 1789.0        True
# 1790.0        True
# 1791.0        True
# 1792.0        True
# 1793.0        True
#
# [5 rows x 52 columns]

# %%
dummy_df3 = pd.merge(drop_df, dummy_df2, on="year")

dummy_df3['birthday'] = pd.to_datetime(dummy_df3['birthday'])
# dummy_df3['birthday'] = dummy_df3['birthday'].astype(str)
# dummy_df3['birthday']= dummy_df3['birthday'].apply(lambda x: x.encode('utf-8'))
# dummy_df3['birthday']= dummy_df3['birthday'].apply(lambda x: x.decode('utf-8'))
dummy_df3['birthday'] = dummy_df3['birthday'].view('int64') // 10**9
# dummy_df3['birthday'] = dummy_df3['birthday'].astype(int)
dummy_df3.head()
dummy_df3.dtypes
# Out:
# birthday                                      int64
# year                                        float64
# nominal_gdp(million_of_dollars)             float64
# nominal_gdp_per_capita_(current_dollars)    float64
# president_Abraham Lincoln                      bool
# president_Andrew Jackson                       bool
# president_Andrew Johnson                       bool
# president_Barack Obama                         bool
# president_Benjamin Harrison                    bool
# president_Bill Clinton                         bool
# president_Calvin Coolidge                      bool
# president_Chester A. Arthur                    bool
# president_Donald Trump                         bool
# president_Dwight D. Eisenhower                 bool
# president_Franklin D. Roosevelt                bool
# president_Franklin Pierce                      bool
# president_George H. W. Bush                    bool
# president_George W. Bush                       bool
# president_George Washington                    bool
# president_Gerald Ford                          bool
# president_Grover Cleveland                     bool
# president_Harry S. Truman                      bool
# president_Herbert Hoover                       bool
# president_James A. Garfield                    bool
# president_James Buchanan                       bool
# president_James K. Polk                        bool
# president_James Madison                        bool
# president_James Monroe                         bool
# president_Jimmy Carter                         bool
# president_Joe Biden                            bool
# president_John Adams                           bool
# president_John F. Kennedy                      bool
# president_John Quincy Adams                    bool
# president_John Tyler                           bool
# president_Lyndon B. Johnson                    bool
# president_Martin Van Buren                     bool
# president_Millard Fillmore                     bool
# president_Richard Nixon                        bool
# president_Ronald Reagan                        bool
# president_Rutherford B. Hayes                  bool
# president_Theodore Roosevelt                   bool
# president_Thomas Jefferson                     bool
# president_Ulysses S. Grant                     bool
# president_Warren G. Harding                    bool
# president_William Henry Harrison               bool
# president_William Howard Taft                  bool
# president_William McKinley                     bool
# president_Woodrow Wilson                       bool
# president_Zachary Taylor                       bool
# party_Democrat                                 bool
# party_Democratic-Republican                    bool
# party_Federalist                               bool
# party_National Union                           bool
# party_Republican                               bool
# party_Whig                                     bool
# party_none                                     bool
# dtype: object

# %%
dummy_df3.shape
# Out:
# (253, 56)

# %%
# # lets split x and y for the modeling
# X = dummy_df3['birthday']
# X= pd.DataFrame(X)

# %%
# y= dummy_df3.drop(columns=['birthday','year'])
# y

# %%
y=dummy_df3["birthday"].values.reshape(-1,1)
X=dummy_df3.loc[:, (dummy_df3.columns != "birthday") & (dummy_df3.columns != "year")]

X
# Out:
#      nominal_gdp(million_of_dollars)  \
# 0                             138.66
# 1                             193.00
# 2                             210.00
# 3                             230.00
# 4                             256.00
# ..                               ...
# 248                      21521395.00
# 249                      21322950.00
# 250                      23594031.00
# 251                      25744108.00
# 252                      27360900.00
#
#      nominal_gdp_per_capita_(current_dollars)  president_Abraham Lincoln  \
# 0                                       20.70                      False
# 1                                       49.10                      False
# 2                                       51.89                      False
# 3                                       55.03                      False
# 4                                       59.67                      False
# ..                                        ...                        ...
# 248                                  65115.12                      False
# 249                                  64266.79                      False
# 250                                  70991.30                      False
# 251                                  77171.74                      False
# 252                                  81623.65                      False
#
#      president_Andrew Jackson  president_Andrew Johnson  \
# 0                       False                     False
# 1                       False                     False
# 2                       False                     False
# 3                       False                     False
# 4                       False                     False
# ..                        ...                       ...
# 248                     False                     False
# 249                     False                     False
# 250                     False                     False
# 251                     False                     False
# 252                     False                     False
#
#      president_Barack Obama  president_Benjamin Harrison  \
# 0                     False                        False
# 1                     False                        False
# 2                     False                        False
# 3                     False                        False
# 4                     False                        False
# ..                      ...                          ...
# 248                   False                        False
# 249                   False                        False
# 250                   False                        False
# 251                   False                        False
# 252                   False                        False
#
#      president_Bill Clinton  president_Calvin Coolidge  \
# 0                     False                      False
# 1                     False                      False
# 2                     False                      False
# 3                     False                      False
# 4                     False                      False
# ..                      ...                        ...
# 248                   False                      False
# 249                   False                      False
# 250                   False                      False
# 251                   False                      False
# 252                   False                      False
#
#      president_Chester A. Arthur  ...  president_William McKinley  \
# 0                          False  ...                       False
# 1                          False  ...                       False
# 2                          False  ...                       False
# 3                          False  ...                       False
# 4                          False  ...                       False
# ..                           ...  ...                         ...
# 248                        False  ...                       False
# 249                        False  ...                       False
# 250                        False  ...                       False
# 251                        False  ...                       False
# 252                        False  ...                       False
#
#      president_Woodrow Wilson  president_Zachary Taylor  party_Democrat  \
# 0                       False                     False           False
# 1                       False                     False           False
# 2                       False                     False           False
# 3                       False                     False           False
# 4                       False                     False           False
# ..                        ...                       ...             ...
# 248                     False                     False           False
# 249                     False                     False           False
# 250                     False                     False            True
# 251                     False                     False            True
# 252                     False                     False            True
#
#      party_Democratic-Republican  party_Federalist  party_National Union  \
# 0                          False             False                 False
# 1                          False             False                 False
# 2                          False             False                 False
# 3                          False             False                 False
# 4                          False             False                 False
# ..                           ...               ...                   ...
# 248                        False             False                 False
# 249                        False             False                 False
# 250                        False             False                 False
# 251                        False             False                 False
# 252                        False             False                 False
#
#      party_Republican  party_Whig  party_none
# 0               False       False        True
# 1               False       False        True
# 2               False       False        True
# 3               False       False        True
# 4               False       False        True
# ..                ...         ...         ...
# 248              True       False       False
# 249              True       False       False
# 250             False       False       False
# 251             False       False       False
# 252             False       False       False
#
# [253 rows x 54 columns]

# %%
X.shape
# Out:
# (253, 54)

# %%
#train_size = int(len(df) * 0.8) X_train, X_test = X[:train_size], X[train_size:] y_train, y_test = y[:train_size], y[train_size:]

# Split the preprocessed data into a training and testing dataset -- choose to stratify so that the classes are more balanced out bc it's a small dataset and imbalanced
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.2, random_state=42)

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler on the training data
X_scaler = scaler.fit(X_train)

# Scale the training and testing data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define a function that builds the model
def build_model(hp):
    nn = tf.keras.models.Sequential()

    # Input layer
    nn.add(Input(shape=(input_shape,)))

    # First hidden layer
    hp_units_1 = hp.Int('units_1', min_value=32, max_value=512, step=32)
    nn.add(Dense(units=hp_units_1, activation='relu'))

    # Optional second hidden layer (conditional on adding a second layer)
    if hp.Boolean('use_second_layer'):
        hp_units_2 = hp.Int('units_2', min_value=32, max_value=512, step=32)
        nn.add(Dense(units=hp_units_2, activation='relu'))

    # Dropout layer
    hp_dropout = hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1)
    nn.add(Dropout(rate=hp_dropout))

    # Output layer
    nn.add(Dense(units=1, activation='sigmoid'))

    # Compile the model with an optimizer hyperparameter
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
    nn.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hp_learning_rate),
               loss='binary_crossentropy',
               metrics=['accuracy'])

    return nn

# %%
# Initialize the Keras Tuner
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,
    executions_per_trial=2,
    directory='my_dir',
    project_name='keras_tuning_example'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Initialize the Keras Tuner
# ----> 2 tuner = RandomSearch(
#       3     build_model,
#       4     objective='val_accuracy',
#       5     max_trials=10,
#       6     executions_per_trial=2,
#       7     directory='my_dir',
#       8     project_name='keras_tuning_example'
#       9 )
#
# File c:\Users\19727\Anaconda3\envs\dev\lib\site-packages\keras_tuner\src\tuners\randomsearch.py:174, in RandomSearch.__init__(self, hypermodel, objective, max_trials, seed, hyperparameters, tune_new_entries, allow_new_entries, max_retries_per_trial, max_consecutive_failed_trials, **kwargs)
#     163 self.seed = seed
#     164 oracle = RandomSearchOracle(
#     165     objective=objective,
#     166     max_trials=max_trials,
#    (...)
#     172     max_consecutive_failed_trials=max_consecutive_failed_trials,
#     173 )
# --> 174 super().__init__(oracle, hypermodel, **kwargs)
#
# File c:\Users\19727\Anaconda3\envs\dev\lib\site-packages\keras_tuner\src\engine\tuner.py:122, in Tuner.__init__(self, oracle, hypermodel, max_model_size, optimizer, loss, metrics, distribution_strategy, directory, project_name, logger, tuner_id, overwrite, executions_per_trial, **kwargs)
#     114 if hypermodel is None and self.__class__.run_trial is Tuner.run_trial:
#     115     raise ValueError(
#     116         "Received `hypermodel=None`. We only allow not specifying "
#     117         "`hypermodel` if the user defines the search space in "
#     118         "`Tuner.run_trial()` by subclassing a `Tuner` class without "
#     119         "using a `HyperModel` instance."
#     120     )
# --> 122 super().__init__(
#     123     oracle=oracle,
#     124     hypermodel=hypermodel,
#     125     directory=directory,
#     126     project_name=project_name,
#     127     logger=logger,
#     128     overwrite=overwrite,
#     129     **kwargs,
#     130 )
#     132 self.max_model_size = max_model_size
#     133 self.optimizer = optimizer
#
# File c:\Users\19727\Anaconda3\envs\dev\lib\site-packages\keras_tuner\src\engine\base_tuner.py:132, in BaseTuner.__init__(self, oracle, hypermodel, directory, project_name, overwrite, **kwargs)
#     129     self.reload()
#     130 else:
#     131     # Only populate initial space if not reloading.
# --> 132     self._populate_initial_space()
#     134 # Run in distributed mode.
#     135 if dist_utils.has_chief_oracle() and not dist_utils.is_chief_oracle():
#     136     # Proxies requests to the chief oracle.
#     137     # Avoid import at the top, to avoid inconsistent protobuf versions.
#
# File c:\Users\19727\Anaconda3\envs\dev\lib\site-packages\keras_tuner\src\engine\base_tuner.py:192, in BaseTuner._populate_initial_space(self)
#     190 self.hypermodel.declare_hyperparameters(hp)
#     191 self.oracle.update_space(hp)
# --> 192 self._activate_all_conditions()
#
# File c:\Users\19727\Anaconda3\envs\dev\lib\site-packages\keras_tuner\src\engine\base_tuner.py:149, in BaseTuner._activate_all_conditions(self)
#     147 hp = self.oracle.get_space()
#     148 while True:
# --> 149     self.hypermodel.build(hp)
#     150     self.oracle.update_space(hp)
#     152     # Update the recorded scopes.
#
# Cell In[18], line 6, in build_model(hp)
#       3 nn = tf.keras.models.Sequential()
#       5 # Input layer
# ----> 6 nn.add(Input(shape=(input_shape,)))
#       8 # First hidden layer
#       9 hp_units_1 = hp.Int('units_1', min_value=32, max_value=512, step=32)
#
# NameError: name 'input_shape' is not defined

# %%
# Run the hyperparameter search
tuner.search(X_train_scaled, y_train, epochs=10, validation_data=(X_test_scaled, y_test))

# %%
# Retrieve the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Get the best model
best_model = tuner.get_best_models(num_models=1)[0]

# Summary of the best model
best_model.summary()

# %%
# Evaluate the best model using the test data
best_model_loss, best_model_accuracy = best_model.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Best Model Loss: {best_model_loss}, Best Model Accuracy: {best_model_accuracy}")

# %%
# Export our model to HDF5 file
best_model.save('model2caite.h5')
